# %%
# Importação das bibliotecas
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
PATH = '/content/drive/My Drive/TCCDataScience/datasets/mlsmall/'
movies = pd.read_csv(PATH+'movies.csv')
#genome_scores = pd.read_csv(PATH+'genome-scores.csv')
tags = pd.read_csv(PATH+'tags.csv')
#genome_tags = pd.read_csv(PATH+'genome-tags.csv')
#Use ratings data to downsample tags data to only movies with ratings 
ratings = pd.read_csv(PATH+'ratings.csv')
links = pd.read_csv(PATH+'links.csv')

# %%
tmdb = pd.read_csv('/content/drive/My Drive/TCCDataScience/datasets/tmdb_5000_movies.csv')

# %%
movies.head(3)
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
#
# [3 rows x 3 columns]

# %%
links.head(3)
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0

# %%
links.drop('imdbId',axis=1, inplace=True)
links.head(3)
# Out:
#    movieId   tmdbId
# 0        1    862.0
# 1        2   8844.0
# 2        3  15602.0

# %%
result = pd.merge(movies, links, how='left', on=['movieId'])

# %%
result.head(3)
#result = result. rename(columns={'movieId':'a'})
# Out:
#    movieId  ...   tmdbId
# 0        1  ...    862.0
# 1        2  ...   8844.0
# 2        3  ...  15602.0
#
# [3 rows x 4 columns]

# %%
tmdb.head(3)
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
#
# [3 rows x 20 columns]

# %%
tmdb = tmdb. rename(columns={'id':'tmdbId'})

# %%
tmdb.head(3)
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
#
# [3 rows x 20 columns]

# %%
# # list the movie titles that survive the filtering
# movie_list_imdb = result.tmdbId.unique().tolist()
# movie_list_imdb[:3]
# Out:
# [862.0, 8844.0, 15602.0]

# %%
# filmes_imdb = tmdb[tmdb.tmdbId.isin(movie_list_imdb)]

# %%
# result = pd.merge(result, filmes_imdb, how='inner', on=['tmdbId'])

# %%
# tmdb.shape
# Out:
# (4803, 20)

# %%
# result.shape
# Out:
# (3537, 23)

# %%
# result.head(3)
# Out:
#    movieId                         title_x  ... vote_average  vote_count
# 0        1                Toy Story (1995)  ...          7.7        5269
# 1       10                GoldenEye (1995)  ...          6.6        1174
# 2       11  American President, The (1995)  ...          6.5         195
#
# [3 rows x 23 columns]

# %%
#  result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3537 entries, 0 to 3536
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movieId               3537 non-null   int64
#  1   title_x               3537 non-null   object
#  2   genres_x              3537 non-null   object
#  3   tmdbId                3537 non-null   float64
#  4   budget                3537 non-null   int64
#  5   genres_y              3537 non-null   object
#  6   homepage              1301 non-null   object
#  7   keywords              3537 non-null   object
#  8   original_language     3537 non-null   object
#  9   original_title        3537 non-null   object
#  10  overview              3537 non-null   object
#  11  popularity            3537 non-null   float64
#  12  production_companies  3537 non-null   object
#  13  production_countries  3537 non-null   object
#  14  release_date          3537 non-null   object
#  15  revenue               3537 non-null   int64
#  16  runtime               3537 non-null   float64
#  17  spoken_languages      3537 non-null   object
#  18  status                3537 non-null   object
#  19  tagline               3206 non-null   object
#  20  title_y               3537 non-null   object
#  21  vote_average          3537 non-null   float64
#  22  vote_count            3537 non-null   int64
# dtypes: float64(4), int64(4), object(15)
# memory usage: 663.2+ KB

# %%
 ratings_f = ratings.groupby('userId').filter(lambda x: len(x) >= 55)
